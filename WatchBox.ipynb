# %%
# Import the libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
watch_data = {
    "Brand": ["Tissot", "Casio", "Titan", "Casio", "Mido", "Citizen", "Apple", "Fossil", "Titan"],
    "Series": ["Couturier", "Edifice", "Classique", "Edifice", "Ocean Star Tribute", "Eco-Drive", "Watch Series 1", "Replica/Fake", "Classique"],
    "Model Number": ["T0356171105100", "ECB950MP-1A", "ND1490SL01", "EF-558D-7AV", "M026.830.17.421.00", "AT0550-11X", "N/A", "CH2519", "EB-218-K95"],
    "Description": [
        "Chronograph Watch", 
        "Motorsports-inspired watch with Bluetooth, speed indicator, and urethane band", 
        "Analog Black Dial Men's Watch with leather strap", 
        "Classic and modern style, silver dial, luminous hands, water-resistant up to 100 meters",
        "Smokey red gradient dial, stainless steel case, water-resistant up to 200 meters", 
        "42mm stainless steel case, brown dial, brown leather strap, Eco-Drive technology", 
        "Available in 38mm and 42mm, dual-core processor, 8GB storage, OLED Retina display",
        "Replica of Fossil CH2519, black dial, stainless steel, water-resistant, and PRICELESS TO ME!", 
        "Pre-owned, gold finish, classic luxurious style"],
    "Movement": ["Swiss Quartz", "Tough Solar (solar powered)", "Quartz", "Quartz", "Automatic Mido Caliber 80", "Eco-Drive", "Dual-core processor", "Quartz", "Quartz"],
    "Crystal": ["Sapphire", "Mineral", "N/A", "Mineral", "Sapphire", "Mineral", "Ion-X", "Mineral", "Mineral"],
    "Case Material": ["Stainless Steel", "Stainless Steel", "", "Stainless Steel", "Stainless Steel", "Stainless Steel", "Aluminum", "Stainless Steel (replica)", "Stainless Steel"],
    "Strap Material": ["Stainless Steel", "Resin (Urethane)", "Leather", "Stainless Steel", "Rubber", "Leather", "Varies", "Bracelet-style (replica)", "Leather"],
    "Clasp Type": ["Butterfly", "Pin Buckle", "Pin Buckle", "Double-Lock, 1-Press, 3-Fold", "Pin Buckle", "Pin Buckle", "Pin-and-Tuck Buckle", "Tang Buckle", "Pin Buckle"],
    "Water Resistance": ["100 meters", "100 meters", "30 meters", "100 meters", "200 meters", "100 meters", "IPX7 - Splash-resistant", "N/A (replica)", "10 meters"],
    "Case Size: Length x Width x Thickness": ["41 mm × 41 mm × 11 mm", "51.2 mm × 48 mm × 13.9 mm", "48 mm × 30 mm × 9 mm", "49.3 mm × 49.3 mm × 14.1 mm", "40.5 mm × 40.5 mm × 13.4 mm", "42 mm × 42 mm × 13 mm", "38.6 mm × 33.3 mm × 10.5 mm", "45 mm × 45 mm × 14.4 mm", "33 mm × 33 mm × 4.4 mm"],
    "Dial Color": ["Black", "Black-Brown dial with colorful touches", "Anthracite Black", "White with Bronze touches", "Smokey red gradient", "Silver", "OLED Retina display with Force Touch (450 nits)", "Black", "Black"],
    "Functions": [
        "Central 60-seconds chronograph hand, 30-minutes and 1/10 of a second counters, ADD and SPLIT functions", 
        "Water Resistance, Smartphone Link Feature, World Time, Timer, Led Back-Light, Calendar, Energy Saver, Stopwatch, Alarm, Hourly Signal, Mute Feature, Battery Display/Alert", 
        "Analog", 
        "Chronograph, Tachymeter, Day and Date Display", 
        "80 Hour Power Reserve, Day and Date Display", 
        "1-second chronograph, 12/24 hour time, Date Display", 
        "Splash resistant, Heart rate sensor, Accelerometer, Gyroscope, Ambient light sensor", 
        "Chronograph, Date (replica)", 
        "Analog"],
    "Release Year": ["2015", "N/A", "~2010-2012", "2011", "N/A", "2011", "2016", "N/A", "2010"],
    "RetailPriceUSD": ["$595.00", "$250.00", "$60.97", "$258.98", "$990.00", "$375.00", "$349.00", "$45.00", "$112.95"],
    "Links": ["https://www.tissotwatches.com/en-us/t0356171105100.html",
    "https://www.casio.com/us/watches/edifice/product.ECB-950MP-1A/",
    "https://www.titan.co.in/product/titan-anthracite-dial-analog-watch-for-men-1490sl01.html",
    "https://www.citywatches.co.uk/product/casio-edifice-chronograph-ef-558d-7av/",
    "https://www.midowatches.com/en/ocean-star-tribute-gradient-m0268301742100.html",
    "https://www.citizenwatch.com/us/en/product/AT0550-11X.html",
    "https://support.apple.com/kb/SP745?locale=en_US",
    "https://www.amazon.com/Fossil-Watch-Stainless-Bracelet-CH2519/dp/B001EDTSNW/ref=cm_cr_arp_d_product_top?ie=UTF8",
    "https://www.ebay.com/itm/335099068790"]
}

# %%
#Checker for column input count lenght mathing population
lengths = [len(v) for v in watch_data.values()]
all_same_length = all(x == lengths[0] for x in lengths)
print("All lists are of the same length:", all_same_length)
# Out:
# All lists are of the same length: True

# %%
# Load your watch collection data
watch_data = {
    "Brand": ["Tissot", "Casio", "Titan", "Casio", "Mido", "Citizen", "Apple", "Fossil", "Titan"],
    "Series": ["Couturier", "Edifice", "Classique", "Edifice", "Ocean Star Tribute", "Eco-Drive", "Watch Series 1", "Replica/Fake", "Classique"],
    "Model Number": ["T0356171105100", "ECB950MP-1A", "ND1490SL01", "EF-558D-7AV", "M026.830.17.421.00", "AT0550-11X", "N/A", "CH2519", "EB-218-K95"],
    "Description": [
        "Chronograph Watch", 
        "Motorsports-inspired watch with Bluetooth, speed indicator, and urethane band", 
        "Analog Black Dial Men's Watch with leather strap", 
        "Classic and modern style, silver dial, luminous hands, water-resistant up to 100 meters",
        "Smokey red gradient dial, stainless steel case, water-resistant up to 200 meters", 
        "42mm stainless steel case, brown dial, brown leather strap, Eco-Drive technology", 
        "Available in 38mm and 42mm, dual-core processor, 8GB storage, OLED Retina display",
        "Replica of Fossil CH2519, black dial, stainless steel, water-resistant, and PRICELESS TO ME!", 
        "Pre-owned, gold finish, classic luxurious style"],
    "Movement": ["Swiss Quartz", "Tough Solar (solar powered)", "Quartz", "Quartz", "Automatic Mido Caliber 80", "Eco-Drive", "Dual-core processor", "Quartz", "Quartz"],
    "Crystal": ["Sapphire", "Mineral", "N/A", "Mineral", "Sapphire", "Mineral", "Ion-X", "Mineral", "Mineral"],
    "Case Material": ["Stainless Steel", "Stainless Steel", "", "Stainless Steel", "Stainless Steel", "Stainless Steel", "Aluminum", "Stainless Steel (replica)", "Stainless Steel"],
    "Strap Material": ["Stainless Steel", "Resin (Urethane)", "Leather", "Stainless Steel", "Rubber", "Leather", "Varies", "Bracelet-style (replica)", "Leather"],
    "Clasp Type": ["Butterfly", "Pin Buckle", "Pin Buckle", "Double-Lock, 1-Press, 3-Fold", "Pin Buckle", "Pin Buckle", "Pin-and-Tuck Buckle", "Tang Buckle", "Pin Buckle"],
    "Water Resistance": ["100 meters", "100 meters", "30 meters", "100 meters", "200 meters", "100 meters", "IPX7 - Splash-resistant", "N/A (replica)", "10 meters"],
    "Case Size: Length x Width x Thickness": ["41 mm × 41 mm × 11 mm", "51.2 mm × 48 mm × 13.9 mm", "48 mm × 30 mm × 9 mm", "49.3 mm × 49.3 mm × 14.1 mm", "40.5 mm × 40.5 mm × 13.4 mm", "42 mm × 42 mm × 13 mm", "38.6 mm × 33.3 mm × 10.5 mm", "45 mm × 45 mm × 14.4 mm", "33 mm × 33 mm × 4.4 mm"],
    "Dial Color": ["Black", "Black-Brown dial with colorful touches", "Anthracite Black", "White with Bronze touches", "Smokey red gradient", "Silver", "OLED Retina display with Force Touch (450 nits)", "Black", "Black"],
    "Functions": [
        "Central 60-seconds chronograph hand, 30-minutes and 1/10 of a second counters, ADD and SPLIT functions", 
        "Water Resistance, Smartphone Link Feature, World Time, Timer, Led Back-Light, Calendar, Energy Saver, Stopwatch, Alarm, Hourly Signal, Mute Feature, Battery Display/Alert", 
        "Analog", 
        "Chronograph, Tachymeter, Day and Date Display", 
        "80 Hour Power Reserve, Day and Date Display", 
        "1-second chronograph, 12/24 hour time, Date Display", 
        "Splash resistant, Heart rate sensor, Accelerometer, Gyroscope, Ambient light sensor", 
        "Chronograph, Date (replica)", 
        "Analog"],
    "Release Year": ["2015", "N/A", "~2010-2012", "2011", "N/A", "2011", "2016", "N/A", "2010"],
    "RetailPriceUSD": ["$595.00", "$250.00", "$60.97", "$258.98", "$990.00", "$375.00", "$349.00", "$45.00", "$112.95"],
    "Links": ["https://www.tissotwatches.com/en-us/t0356171105100.html",
    "https://www.casio.com/us/watches/edifice/product.ECB-950MP-1A/",
    "https://www.titan.co.in/product/titan-anthracite-dial-analog-watch-for-men-1490sl01.html",
    "https://www.citywatches.co.uk/product/casio-edifice-chronograph-ef-558d-7av/",
    "https://www.midowatches.com/en/ocean-star-tribute-gradient-m0268301742100.html",
    "https://www.citizenwatch.com/us/en/product/AT0550-11X.html",
    "https://support.apple.com/kb/SP745?locale=en_US",
    "https://www.amazon.com/Fossil-Watch-Stainless-Bracelet-CH2519/dp/B001EDTSNW/ref=cm_cr_arp_d_product_top?ie=UTF8",
    "https://www.ebay.com/itm/335099068790"]
}

# Convert to DataFrame
watches_df = pd.DataFrame(watch_data)
print(watches_df)
# Out:
#      Brand              Series        Model Number  \
# 0   Tissot           Couturier      T0356171105100
# 1    Casio             Edifice         ECB950MP-1A
# 2    Titan           Classique          ND1490SL01
# 3    Casio             Edifice         EF-558D-7AV
# 4     Mido  Ocean Star Tribute  M026.830.17.421.00
# 5  Citizen           Eco-Drive          AT0550-11X
# 6    Apple      Watch Series 1                 N/A
# 7   Fossil        Replica/Fake              CH2519
# 8    Titan           Classique          EB-218-K95
#
#                                          Description  \
# 0                                  Chronograph Watch
# 1  Motorsports-inspired watch with Bluetooth, spe...
# 2   Analog Black Dial Men's Watch with leather strap
# 3  Classic and modern style, silver dial, luminou...
# 4  Smokey red gradient dial, stainless steel case...
# 5  42mm stainless steel case, brown dial, brown l...
# 6  Available in 38mm and 42mm, dual-core processo...
# 7  Replica of Fossil CH2519, black dial, stainles...
# 8    Pre-owned, gold finish, classic luxurious style
#
#                       Movement   Crystal              Case Material  \
# 0                 Swiss Quartz  Sapphire            Stainless Steel
# 1  Tough Solar (solar powered)   Mineral            Stainless Steel
# 2                       Quartz       N/A
# 3                       Quartz   Mineral            Stainless Steel
# 4    Automatic Mido Caliber 80  Sapphire            Stainless Steel
# 5                    Eco-Drive   Mineral            Stainless Steel
# 6          Dual-core processor     Ion-X                   Aluminum
# 7                       Quartz   Mineral  Stainless Steel (replica)
# 8                       Quartz   Mineral            Stainless Steel
#
#              Strap Material                    Clasp Type  \
# 0           Stainless Steel                     Butterfly
# 1          Resin (Urethane)                    Pin Buckle
# 2                   Leather                    Pin Buckle
# 3           Stainless Steel  Double-Lock, 1-Press, 3-Fold
# 4                    Rubber                    Pin Buckle
# 5                   Leather                    Pin Buckle
# 6                    Varies           Pin-and-Tuck Buckle
# 7  Bracelet-style (replica)                   Tang Buckle
# 8                   Leather                    Pin Buckle
#
#           Water Resistance Case Size: Length x Width x Thickness  \
# 0               100 meters                 41 mm × 41 mm × 11 mm
# 1               100 meters             51.2 mm × 48 mm × 13.9 mm
# 2                30 meters                  48 mm × 30 mm × 9 mm
# 3               100 meters           49.3 mm × 49.3 mm × 14.1 mm
# 4               200 meters           40.5 mm × 40.5 mm × 13.4 mm
# 5               100 meters                 42 mm × 42 mm × 13 mm
# 6  IPX7 - Splash-resistant           38.6 mm × 33.3 mm × 10.5 mm
# 7            N/A (replica)               45 mm × 45 mm × 14.4 mm
# 8                10 meters                33 mm × 33 mm × 4.4 mm
#
#                                         Dial Color  \
# 0                                            Black
# 1           Black-Brown dial with colorful touches
# 2                                 Anthracite Black
# 3                        White with Bronze touches
# 4                              Smokey red gradient
# 5                                           Silver
# 6  OLED Retina display with Force Touch (450 nits)
# 7                                            Black
# 8                                            Black
#
#                                            Functions Release Year  \
# 0  Central 60-seconds chronograph hand, 30-minute...         2015
# 1  Water Resistance, Smartphone Link Feature, Wor...          N/A
# 2                                             Analog   ~2010-2012
# 3      Chronograph, Tachymeter, Day and Date Display         2011
# 4        80 Hour Power Reserve, Day and Date Display          N/A
# 5  1-second chronograph, 12/24 hour time, Date Di...         2011
# 6  Splash resistant, Heart rate sensor, Accelerom...         2016
# 7                        Chronograph, Date (replica)          N/A
# 8                                             Analog         2010
#
#   RetailPriceUSD                                              Links
# 0        $595.00  https://www.tissotwatches.com/en-us/t035617110...
# 1        $250.00  https://www.casio.com/us/watches/edifice/produ...
# 2         $60.97  https://www.titan.co.in/product/titan-anthraci...
# 3        $258.98  https://www.citywatches.co.uk/product/casio-ed...
# 4        $990.00  https://www.midowatches.com/en/ocean-star-trib...
# 5        $375.00  https://www.citizenwatch.com/us/en/product/AT0...
# 6        $349.00    https://support.apple.com/kb/SP745?locale=en_US
# 7         $45.00  https://www.amazon.com/Fossil-Watch-Stainless-...
# 8        $112.95              https://www.ebay.com/itm/335099068790

# %%
# Print out the column names to verify
print("Column names in DataFrame:", watches_df.columns)
# Out:
# Column names in DataFrame: Index(['Brand', 'Series', 'Model Number', 'Description', 'Movement', 'Crystal',
#        'Case Material', 'Strap Material', 'Clasp Type', 'Water Resistance',
#        'Case Size: Length x Width x Thickness', 'Dial Color', 'Functions',
#        'Release Year', 'RetailPriceUSD', 'Links'],
#       dtype='object')

# %%
# DataFrame setup
watch_data = {
    "Brand": ["Tissot", "Casio", "Titan", "Casio", "Mido", "Citizen", "Apple", "Fossil", "Titan"],
    "Series": ["Couturier", "Edifice", "Classique", "Edifice", "Ocean Star Tribute", "Eco-Drive", "Watch Series 1", "Replica/Fake", "Classique"],
    "Model Number": ["T0356171105100", "ECB950MP-1A", "ND1490SL01", "EF-558D-7AV", "M026.830.17.421.00", "AT0550-11X", "N/A", "CH2519", "EB-218-K95"],
    "Description": [
        "Chronograph Watch", 
        "Motorsports-inspired watch with Bluetooth, speed indicator, and urethane band", 
        "Analog Black Dial Men's Watch with leather strap", 
        "Classic and modern style, silver dial, luminous hands, water-resistant up to 100 meters",
        "Smokey red gradient dial, stainless steel case, water-resistant up to 200 meters", 
        "42mm stainless steel case, brown dial, brown leather strap, Eco-Drive technology", 
        "Available in 38mm and 42mm, dual-core processor, 8GB storage, OLED Retina display",
        "Replica of Fossil CH2519, black dial, stainless steel, water-resistant, and PRICELESS TO ME!", 
        "Pre-owned, gold finish, classic luxurious style"],
    "Movement": ["Swiss Quartz", "Tough Solar (solar powered)", "Quartz", "Quartz", "Automatic Mido Caliber 80", "Eco-Drive", "Dual-core processor", "Quartz", "Quartz"],
    "Crystal": ["Sapphire", "Mineral", "N/A", "Mineral", "Sapphire", "Mineral", "Ion-X", "Mineral", "Mineral"],
    "Case Material": ["Stainless Steel", "Stainless Steel", "", "Stainless Steel", "Stainless Steel", "Stainless Steel", "Aluminum", "Stainless Steel (replica)", "Stainless Steel"],
    "Strap Material": ["Stainless Steel", "Resin (Urethane)", "Leather", "Stainless Steel", "Rubber", "Leather", "Varies", "Bracelet-style (replica)", "Leather"],
    "Clasp Type": ["Butterfly", "Pin Buckle", "Pin Buckle", "Double-Lock, 1-Press, 3-Fold", "Pin Buckle", "Pin Buckle", "Pin-and-Tuck Buckle", "Tang Buckle", "Pin Buckle"],
    "Water Resistance": ["100 meters", "100 meters", "30 meters", "100 meters", "200 meters", "100 meters", "IPX7 - Splash-resistant", "N/A (replica)", "10 meters"],
    "Case Size: Length x Width x Thickness": ["41 mm × 41 mm × 11 mm", "51.2 mm × 48 mm × 13.9 mm", "48 mm × 30 mm × 9 mm", "49.3 mm × 49.3 mm × 14.1 mm", "40.5 mm × 40.5 mm × 13.4 mm", "42 mm × 42 mm × 13 mm", "38.6 mm × 33.3 mm × 10.5 mm", "45 mm × 45 mm × 14.4 mm", "33 mm × 33 mm × 4.4 mm"],
    "Dial Color": ["Black", "Black-Brown dial with colorful touches", "Anthracite Black", "White with Bronze touches", "Smokey red gradient", "Silver", "OLED Retina display with Force Touch (450 nits)", "Black", "Black"],
    "Functions": [
        "Central 60-seconds chronograph hand, 30-minutes and 1/10 of a second counters, ADD and SPLIT functions", 
        "Water Resistance, Smartphone Link Feature, World Time, Timer, Led Back-Light, Calendar, Energy Saver, Stopwatch, Alarm, Hourly Signal, Mute Feature, Battery Display/Alert", 
        "Analog", 
        "Chronograph, Tachymeter, Day and Date Display", 
        "80 Hour Power Reserve, Day and Date Display", 
        "1-second chronograph, 12/24 hour time, Date Display", 
        "Splash resistant, Heart rate sensor, Accelerometer, Gyroscope, Ambient light sensor", 
        "Chronograph, Date (replica)", 
        "Analog"],
    "Release Year": ["2015", "N/A", "~2010-2012", "2011", "N/A", "2011", "2016", "N/A", "2010"],
    "RetailPriceUSD": ["595.00", "250.00", "60.97", "258.98", "990.00", "375.00", "349.00", "45.00", "112.95"],
    "Links": ["https://www.tissotwatches.com/en-us/t0356171105100.html",
    "https://www.casio.com/us/watches/edifice/product.ECB-950MP-1A/",
    "https://www.titan.co.in/product/titan-anthracite-dial-analog-watch-for-men-1490sl01.html",
    "https://www.citywatches.co.uk/product/casio-edifice-chronograph-ef-558d-7av/",
    "https://www.midowatches.com/en/ocean-star-tribute-gradient-m0268301742100.html",
    "https://www.citizenwatch.com/us/en/product/AT0550-11X.html",
    "https://support.apple.com/kb/SP745?locale=en_US",
    "https://www.amazon.com/Fossil-Watch-Stainless-Bracelet-CH2519/dp/B001EDTSNW/ref=cm_cr_arp_d_product_top?ie=UTF8",
    "https://www.ebay.com/itm/335099068790"]
}

watches_df = pd.DataFrame(watch_data)
# Define the list of HTML code for the 9 thumbnail-linked image sources
image_html_sources = [
    '<a href="https://ibb.co/db4MSc9"><img src="https://i.ibb.co/db4MSc9/T0356171105100.png" alt="T0356171105100" border="0"></a>','<a href="https://ibb.co/T87sWGn"><img src="https://i.ibb.co/T87sWGn/ECB950-MP-1-A.png" alt="ECB950-MP-1-A" border="0"></a>','<a href="https://ibb.co/Y2bcr0y"><img src="https://i.ibb.co/Y2bcr0y/ND1490-SL01.png" alt="ND1490-SL01" border="0"></a>','<a href="https://ibb.co/h84JXnw"><img src="https://i.ibb.co/h84JXnw/EF-558-D-7-AV.png" alt="EF-558-D-7-AV" border="0"></a>','<a href="https://ibb.co/5hxGnkP"><img src="https://i.ibb.co/5hxGnkP/M026-830-17-421-00.png" alt="M026-830-17-421-00" border="0"></a>','<a href="https://ibb.co/dbx15q5"><img src="https://i.ibb.co/dbx15q5/AT0550-11-X.png" alt="AT0550-11-X" border="0"></a>','<a href="https://ibb.co/vX3Dtpt"><img src="https://i.ibb.co/vX3Dtpt/N-A.png" alt="N-A" border="0"></a>','<a href="https://ibb.co/Cnqj94C"><img src="https://i.ibb.co/Cnqj94C/CH2519.png" alt="CH2519" border="0"></a>','<a href="https://ibb.co/Bgyx58t"><img src="https://i.ibb.co/Bgyx58t/EB-218-K95.png" alt="EB-218-K95" border="0"></a>'
                     ]

# Create a new column 'Thumbnails' in the DataFrame
watches_df['Thumbnails'] = image_html_sources
# Get the list of columns in the DataFrame
columns = list(watches_df.columns)

# Reorder the columns. Insert 'Links' at index 1 and 'Thumbnails' at index 2
columns.insert(1, columns.pop(columns.index('Links')))
columns.insert(2, columns.pop(columns.index('Thumbnails')))

# Reassign the reordered columns to the DataFrame
watches_df = watches_df[columns]

# Rename the 'Links' column to 'Watch Name'
watches_df.rename(columns={'Links': 'Watch Names'}, inplace=True)

# Function to calculate brightness of a color (used for contrast)
def brightness(hex_color):
    hex_color = hex_color.lstrip('#')
    rgb = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
    return (0.299 * rgb[0] + 0.587 * rgb[1] + 0.114 * rgb[2]) / 255

# Function to map color descriptions to color codes
def color_mapper(color_description):
    color_map = {
        'black': '#000000', 'white': '#FFFFFF', 'red': '#FF0000', 
        'blue': '#0000FF', 'green': '#008000', 'yellow': '#FFFF00', 
        'silver': '#C0C0C0', 'gold': '#FFD700', 'bronze': '#CD7F32',
        'gray': '#808080', 'grey': '#808080', 'pink': '#FFC0CB',
        'purple': '#800080', 'orange': '#FFA500', 'brown': '#A52A2A',
        'anthracite': '#303030', 'smokey red': '#B22222', # Add other colors as needed
    }
    for color_word, hex_color in color_map.items():
        if color_word in color_description.lower():
            return hex_color
    return '#FFFFFF'  # Default color

# Function to format the 'Watch Names' column with smart names
def format_watch_names(val):
    # Retrieve the brand and series based on the 'val' link
    brand = watches_df.loc[watches_df['Watch Names'] == val, 'Brand'].iloc[0]
    series = watches_df.loc[watches_df['Watch Names'] == val, 'Series'].iloc[0]
    label = f"{brand} {series}" if series else brand
    return f'<a href="{val}" target="_blank">{label}</a>'

# Function to apply styling to 'Dial Color' column
def style_dial_color(row):
    dial_color = row['Dial Color']
    bg_color = color_mapper(dial_color)
    if bg_color:
        text_color = "#FFFFFF" if brightness(bg_color) < 0.5 else "#000000"
        return [f'background-color: {bg_color}; color: {text_color}']
    return [''] * len(row)

# Check if 'Dial Color' column exists in the DataFrame
if 'Dial Color' not in watches_df.columns:
    print("Column 'Dial Color' not found in DataFrame.")
else:
    # Apply styling to the DataFrame
        styled_df = watches_df.style.apply(
            lambda row: style_dial_color(row), axis=1, subset=['Dial Color']
        ).format(
            {'Watch Names': format_watch_names}  # Updated to use the 'Watch Names' column
        ).set_table_styles([
            {'selector': 'th', 'props': [('background-color', '#f4f4f4'), ('color', 'black'), ('font-family', 'Arial')]},
            {'selector': 'td', 'props': [('font-family', 'Arial')]}
        ]).set_properties(**{
            'border-color': 'black',
            'border-width': '1px',
            'border-style': 'solid'
        }).background_gradient(cmap='Blues', subset=['RetailPriceUSD'])

# Display the styled DataFrame
display(styled_df)
# Out:
# <style type="text/css">
# #T_f6b78_ th {
#   background-color: #f4f4f4;
#   color: black;
#   font-family: Arial;
# }
# #T_f6b78_ td {
#   font-family: Arial;
# }
# #T_f6b78_row0_col0, #T_f6b78_row0_col1, #T_f6b78_row0_col2, #T_f6b78_row0_col3, #T_f6b78_row0_col4, #T_f6b78_row0_col5, #T_f6b78_row0_col6, #T_f6b78_row0_col7, #T_f6b78_row0_col8, #T_f6b78_row0_col9, #T_f6b78_row0_col10, #T_f6b78_row0_col11, #T_f6b78_row0_col12, #T_f6b78_row0_col14, #T_f6b78_row0_col15, #T_f6b78_row1_col0, #T_f6b78_row1_col1, #T_f6b78_row1_col2, #T_f6b78_row1_col3, #T_f6b78_row1_col4, #T_f6b78_row1_col5, #T_f6b78_row1_col6, #T_f6b78_row1_col7, #T_f6b78_row1_col8, #T_f6b78_row1_col9, #T_f6b78_row1_col10, #T_f6b78_row1_col11, #T_f6b78_row1_col12, #T_f6b78_row1_col14, #T_f6b78_row1_col15, #T_f6b78_row2_col0, #T_f6b78_row2_col1, #T_f6b78_row2_col2, #T_f6b78_row2_col3, #T_f6b78_row2_col4, #T_f6b78_row2_col5, #T_f6b78_row2_col6, #T_f6b78_row2_col7, #T_f6b78_row2_col8, #T_f6b78_row2_col9, #T_f6b78_row2_col10, #T_f6b78_row2_col11, #T_f6b78_row2_col12, #T_f6b78_row2_col14, #T_f6b78_row2_col15, #T_f6b78_row3_col0, #T_f6b78_row3_col1, #T_f6b78_row3_col2, #T_f6b78_row3_col3, #T_f6b78_row3_col4, #T_f6b78_row3_col5, #T_f6b78_row3_col6, #T_f6b78_row3_col7, #T_f6b78_row3_col8, #T_f6b78_row3_col9, #T_f6b78_row3_col10, #T_f6b78_row3_col11, #T_f6b78_row3_col12, #T_f6b78_row3_col14, #T_f6b78_row3_col15, #T_f6b78_row4_col0, #T_f6b78_row4_col1, #T_f6b78_row4_col2, #T_f6b78_row4_col3, #T_f6b78_row4_col4, #T_f6b78_row4_col5, #T_f6b78_row4_col6, #T_f6b78_row4_col7, #T_f6b78_row4_col8, #T_f6b78_row4_col9, #T_f6b78_row4_col10, #T_f6b78_row4_col11, #T_f6b78_row4_col12, #T_f6b78_row4_col14, #T_f6b78_row4_col15, #T_f6b78_row5_col0, #T_f6b78_row5_col1, #T_f6b78_row5_col2, #T_f6b78_row5_col3, #T_f6b78_row5_col4, #T_f6b78_row5_col5, #T_f6b78_row5_col6, #T_f6b78_row5_col7, #T_f6b78_row5_col8, #T_f6b78_row5_col9, #T_f6b78_row5_col10, #T_f6b78_row5_col11, #T_f6b78_row5_col12, #T_f6b78_row5_col14, #T_f6b78_row5_col15, #T_f6b78_row6_col0, #T_f6b78_row6_col1, #T_f6b78_row6_col2, #T_f6b78_row6_col3, #T_f6b78_row6_col4, #T_f6b78_row6_col5, #T_f6b78_row6_col6, #T_f6b78_row6_col7, #T_f6b78_row6_col8, #T_f6b78_row6_col9, #T_f6b78_row6_col10, #T_f6b78_row6_col11, #T_f6b78_row6_col12, #T_f6b78_row6_col14, #T_f6b78_row6_col15, #T_f6b78_row7_col0, #T_f6b78_row7_col1, #T_f6b78_row7_col2, #T_f6b78_row7_col3, #T_f6b78_row7_col4, #T_f6b78_row7_col5, #T_f6b78_row7_col6, #T_f6b78_row7_col7, #T_f6b78_row7_col8, #T_f6b78_row7_col9, #T_f6b78_row7_col10, #T_f6b78_row7_col11, #T_f6b78_row7_col12, #T_f6b78_row7_col14, #T_f6b78_row7_col15, #T_f6b78_row8_col0, #T_f6b78_row8_col1, #T_f6b78_row8_col2, #T_f6b78_row8_col3, #T_f6b78_row8_col4, #T_f6b78_row8_col5, #T_f6b78_row8_col6, #T_f6b78_row8_col7, #T_f6b78_row8_col8, #T_f6b78_row8_col9, #T_f6b78_row8_col10, #T_f6b78_row8_col11, #T_f6b78_row8_col12, #T_f6b78_row8_col14, #T_f6b78_row8_col15 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
# }
# #T_f6b78_row0_col13, #T_f6b78_row1_col13, #T_f6b78_row2_col13, #T_f6b78_row7_col13, #T_f6b78_row8_col13 {
#   background-color: #000000;
#   color: #FFFFFF;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
# }
# #T_f6b78_row0_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_f6b78_row1_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_f6b78_row2_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f6b78_row3_col13, #T_f6b78_row6_col13 {
#   background-color: #FFFFFF;
#   color: #000000;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
# }
# #T_f6b78_row3_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_f6b78_row4_col13 {
#   background-color: #FF0000;
#   color: #FFFFFF;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
# }
# #T_f6b78_row4_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f6b78_row5_col13 {
#   background-color: #C0C0C0;
#   color: #000000;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
# }
# #T_f6b78_row5_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_f6b78_row6_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_f6b78_row7_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f6b78_row8_col16 {
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   background-color: #e9f2fa;
#   color: #000000;
# }
# </style>
# <table id="T_f6b78_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Brand</th>
#       <th class="col_heading level0 col1" >Watch Names</th>
#       <th class="col_heading level0 col2" >Thumbnails</th>
#       <th class="col_heading level0 col3" >Series</th>
#       <th class="col_heading level0 col4" >Model Number</th>
#       <th class="col_heading level0 col5" >Description</th>
#       <th class="col_heading level0 col6" >Movement</th>
#       <th class="col_heading level0 col7" >Crystal</th>
#       <th class="col_heading level0 col8" >Case Material</th>
#       <th class="col_heading level0 col9" >Strap Material</th>
#       <th class="col_heading level0 col10" >Clasp Type</th>
#       <th class="col_heading level0 col11" >Water Resistance</th>
#       <th class="col_heading level0 col12" >Case Size: Length x Width x Thickness</th>
#       <th class="col_heading level0 col13" >Dial Color</th>
#       <th class="col_heading level0 col14" >Functions</th>
#       <th class="col_heading level0 col15" >Release Year</th>
#       <th class="col_heading level0 col16" >RetailPriceUSD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6b78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6b78_row0_col0" class="data row0 col0" >Tissot</td>
#       <td id="T_f6b78_row0_col1" class="data row0 col1" ><a href="https://www.tissotwatches.com/en-us/t0356171105100.html" target="_blank">Tissot Couturier</a></td>
#       <td id="T_f6b78_row0_col2" class="data row0 col2" ><a href="https://ibb.co/db4MSc9"><img src="https://i.ibb.co/db4MSc9/T0356171105100.png" alt="T0356171105100" border="0"></a></td>
#       <td id="T_f6b78_row0_col3" class="data row0 col3" >Couturier</td>
#       <td id="T_f6b78_row0_col4" class="data row0 col4" >T0356171105100</td>
#       <td id="T_f6b78_row0_col5" class="data row0 col5" >Chronograph Watch</td>
#       <td id="T_f6b78_row0_col6" class="data row0 col6" >Swiss Quartz</td>
#       <td id="T_f6b78_row0_col7" class="data row0 col7" >Sapphire</td>
#       <td id="T_f6b78_row0_col8" class="data row0 col8" >Stainless Steel</td>
#       <td id="T_f6b78_row0_col9" class="data row0 col9" >Stainless Steel</td>
#       <td id="T_f6b78_row0_col10" class="data row0 col10" >Butterfly</td>
#       <td id="T_f6b78_row0_col11" class="data row0 col11" >100 meters</td>
#       <td id="T_f6b78_row0_col12" class="data row0 col12" >41 mm × 41 mm × 11 mm</td>
#       <td id="T_f6b78_row0_col13" class="data row0 col13" >Black</td>
#       <td id="T_f6b78_row0_col14" class="data row0 col14" >Central 60-seconds chronograph hand, 30-minutes and 1/10 of a second counters, ADD and SPLIT functions</td>
#       <td id="T_f6b78_row0_col15" class="data row0 col15" >2015</td>
#       <td id="T_f6b78_row0_col16" class="data row0 col16" >595.00</td>
#     </tr>
#     <tr>
#       <th id="T_f6b78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6b78_row1_col0" class="data row1 col0" >Casio</td>
#       <td id="T_f6b78_row1_col1" class="data row1 col1" ><a href="https://www.casio.com/us/watches/edifice/product.ECB-950MP-1A/" target="_blank">Casio Edifice

# %% [markdown]
# #### Now we use 'app.py' to open up an html version of your watch collection through terminal. Please navigate to your clone repo in your local terminal and run the command 'python app.py'
